# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import seaborn as sb

# %% [markdown]
# Load matrix from disk

# %%
zip_desc = np.load('lymphoma_mtx.npz')
matrix = zip_desc.items()[0][1]
# df = pd.DataFrame(matrix)

# %% [markdown]
# Print heatmap

# %%
sb.set(color_codes=True)
sb.heatmap(matrix, xticklabels=False, yticklabels=False)
